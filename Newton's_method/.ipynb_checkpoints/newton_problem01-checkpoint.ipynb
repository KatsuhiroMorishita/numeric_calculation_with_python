# %% [markdown]
# # 出題内容
# 以下の式を𝑥について解け。ここで、xの初期値を4とする。
#
# <img src="newton_p01_1.png">

# %%
# まず、関数のグラフを確認
import numpy as np
import matplotlib.pyplot as plt

# ↓jupyter上でグラフをズームするための命令
# %matplotlib notebook

def f(x):
    return 2 * np.sin(3*x) - 1/7

x = np.arange(-5, 5, 0.01)
y = f(x)

plt.plot(x, y)
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# 解答例
import numpy as np
import matplotlib.pyplot as plt

def diff(func, x, dx): # funcは微分したい方程式の値を返す関数
    return (func(x + dx) - func(x)) / dx

def calc_newton(func, x_init, dx): # 汎用ニュートン法で解を求める関数
    x = x_init
    y = float("inf")
    count = 0
    e = 1.0

    while abs(y) > 0.01 and count < 1000 and e > 0.00001:
        y = func(x)
        dydx = diff(func, x, dx)
        new_x = -y / dydx + x
        e = abs(new_x - x) / (abs(x) + 0.0000000001)
        x = new_x
        count += 1

    print(x, count) # 使う時にはコメントアウトした方が良い
    return x


def main():
    pos_x = calc_newton(f, 4, 0.01) # 交点のx座標を求める。関数f()は上のセルで定義したものを使う（上のセルを先に実行すること）
    print("y = 0との交点xは、", pos_x)
        
if __name__ == "__main__":
    main()
# Out:
# 4.21262023589 3
# y = 0との交点xは、 4.21262023589
