# %% [markdown]
# # pandas　AMeDASデータクレンジング
# * amedas_0962_mini.csvはAMeDAS熊本観測局のデータである
# * 1時間当たりの降水量が10 (mm/h)以上であった時間数を返す関数test()を実装せよ
# * ひな形の引数dfはpandasのDataFrame型とする
# * main()内において、上記のAMeDASのデータを読み出し、test()に渡すことで動作を確認せよ
#
# データソース：
# [https://raw.githubusercontent.com/KatsuhiroMorishita/numeric_calculation_with_python/master/Pandas/amedas_0962_mini.csv](https://raw.githubusercontent.com/KatsuhiroMorishita/numeric_calculation_with_python/master/Pandas/amedas_0962_mini.csv)
#
#
# ヒント：
# AMeDASの観測データには、数値に" )"や" ]"などがくっついていることがある。これは観測値の信頼性が低い場合などに付与される文字列である。統計処理上で気をつけるように付与されたものだが、数値化する際にエラーが発生してしまう。ここでは、エラーが出ないようにデータを処理する例を示す。なお、データを使えるように処理する事を単に前処理といったり、データクレンジング（洗濯）という。

# %%
#ひな形

def test(df):
    y = "ひな形"
    return y

def main():
    pass

if __name__ == "__main__":
    main()

# %% [markdown]
# ## 解答例を示す前に、諸々試しておく

# %%
# データの読み込みと、列ごとの型の確認
import pandas as pd

# データの読み込み
df = pd.read_csv("https://raw.githubusercontent.com/KatsuhiroMorishita/numeric_calculation_with_python/master/Pandas/amedas_0962_mini.csv", na_values=["×", "--", "///"])    # 可能な限り、欠損値はNaNに置換する
print(df.dtypes)       # 型の確認
df
# Out:
# 日時               object
# 時                 int64
# 降水量(mm)          object
# 気温(度)           float64
# 風速・風向(m/s)風速     object
# 風速・風向(m/s)風向     object
# 日照時間(h)          object
# 雪(cm)降雪         float64
# 雪(cm)積雪         float64
# dtype: object
#                        日時   時 降水量(mm)  気温(度) 風速・風向(m/s)風速 風速・風向(m/s)風向  \
# 0     2009-01-01 00:00:00  24     0.0    4.1            3          北北西
# 1     2009-01-01 01:00:00   1     0.0    4.4            4          北北西
# 2     2009-01-01 02:00:00   2     0.0    4.9            7          西北西
# 3     2009-01-01 03:00:00   3     0.0    4.3            4           北西
# 4     2009-01-01 04:00:00   4     0.0    3.4            2          北北西
# 5     2009-01-01 05:00:00   5     0.0    3.7            4           北西
# 6     2009-01-01 06:00:00   6     0.0    2.8            3            北
# 7     2009-01-01 07:00:00   7     0.0    2.9            3            北
# 8     2009-01-01 08:00:00   8     0.0    3.1            2          北北西
# 9     2009-01-01 09:00:00   9     0.0    4.2            4          北北東
# 10    2009-01-01 10:00:00  10     0.0    2.5            5          北北西
# 11    2009-01-01 11:00:00  11     0.0    4.0            5          北北西
# 12    2009-01-01 12:00:00  12     0.0    4.8            4          北北西
# 13    2009-01-01 13:00:00  13     0.0    5.3            4           北西
# 14    2009-01-01 14:00:00  14     0.0    4.1            6          北北西
# 15    2009-01-01 15:00:00  15     0.0    4.1            6          北北西
# 16    2009-01-01 16:00:00  16     0.0    3.8            6          北北西
# 17    2009-01-01 17:00:00  17     0.0    3.2            4           北西
# 18    2009-01-01 18:00:00  18     0.0    2.2            3           北西
# 19    2009-01-01 19:00:00  19     0.0    2.3            3          北北西
# 20    2009-01-01 20:00:00  20     0.0    1.6            1            西
# 21    2009-01-01 21:00:00  21     0.0    2.7            2           南西
# 22    2009-01-01 22:00:00  22     0.0    2.7            1            西
# 23    2009-01-01 23:00:00  23     0.0    2.5            2            西
# 24    2009-01-02 00:00:00  24     0.0    2.8            2          西北西
# 25    2009-01-02 01:00:00   1     0.0    2.3            2          北北西
# 26    2009-01-02 02:00:00   2     0.0    2.4            2          北北西
# 27    2009-01-02 03:00:00   3     0.0    2.3            2          北北西
# 28    2009-01-02 04:00:00   4     0.0    0.6            1           北西
# 29    2009-01-02 05:00:00   5     0.0   -0.1            1          北北東
# ...                   ...  ..     ...    ...          ...          ...
# 8730  2009-12-30 18:00:00  18     0.0    8.3          2.0          西北西
# 8731  2009-12-30 19:00:00  19     0.0    7.9          2.5          西北西
# 8732  2009-12-30 20:00:00  20     0.0    7.6          2.8           南西
# 8733  2009-12-30 21:00:00  21     0.0    7.2          4.4          北北西
# 8734  2009-12-30 22:00:00  22     0.0    6.5          4.1          西北西
# 8735  2009-12-30 23:00:00  23     0.0    6.0          3.9           北西
# 8736  2009-12-31 00:00:00  24     0.0    5.8          5.0           北西
# 8737  2009-12-31 01:00:00   1     0.0    5.4          4.5          西北西
# 8738  2009-12-31 02:00:00   2     0.0    5.1          3.5           北西
# 8739  2009-12-31 03:00:00   3     0.0    4.3          3.5          北北西
# 8740  2009-12-31 04:00:00   4     0.0    3.4          4.2          北北西
# 8741  2009-12-31 05:00:00   5     0.0    3.0          5.4          北北西
# 8742  2009-12-31 06:00:00   6     0.0    2.4          5.4          北北西
# 8743  2009-12-31 07:00:00   7     0.0    2.4          7.3           北西
# 8744  2009-12-31 08:00:00   8     0.0    2.7          4.9            北
# 8745  2009-12-31 09:00:00   9     0.0    2.7          3.9          北北西
# 8746  2009-12-31 10:00:00  10     0.0    3.0          4.2          北北西
# 8747  2009-12-31 11:00:00  11     0.0    3.3          5.0          北北西
# 8748  2009-12-31 12:00:00  12     0.0    4.1          5.6           北西
# 8749  2009-12-31 13:00:00  13     0.0    4.6          4.5           北西
# 8750  2009-12-31 14:00:00  14     0.0    3.4          5.0          北北西
# 8751  2009-12-31 15:00:00  15     0.0    3.7          4.7           北西
# 8752  2009-12-31 16:00:00  16     0.0    3.4          5.3          西北西
# 8753  2009-12-31 17:00:00  17     0.0    2.8          2.7            北
# 8754  2009-12-31 18:00:00  18     0.0    2.2          2.7          北北東
# 8755  2009-12-31 19:00:00  19     0.0    2.1          2.6            北
# 8756  2009-12-31 20:00:00  20     0.0    1.4          0.6            北
# 8757  2009-12-31 21:00:00  21     0.0    1.8          3.0           北西
# 8758  2009-12-31 22:00:00  22     0.0    1.8          4.2           北西
# 8759  2009-12-31 23:00:00  23     0.0    1.5          3.1          北北西
#
#      日照時間(h)  雪(cm)降雪  雪(cm)積雪
# 0        0.0      NaN      NaN
# 1        0.0      NaN      NaN
# 2        0.0      NaN      NaN
# 3        0.0      NaN      NaN
# 4        0.0      NaN      NaN
# 5        0.0      NaN      NaN
# 6        0.0      NaN      NaN
# 7        0.0      NaN      NaN
# 8        0.1      NaN      NaN
# 9        0.5      NaN      NaN
# 10       0.7      NaN      NaN
# 11       0.1      NaN      NaN
# 12       0.3      NaN      NaN
# 13       0.2      NaN      NaN
# 14       0.3      NaN      NaN
# 15       0.3      NaN      NaN
# 16       0.0      NaN      NaN
# 17       0.0      NaN      NaN
# 18       0.0      NaN      NaN
# 19       0.0      NaN      NaN
# 20       0.0      NaN      NaN
# 21       0.0      NaN      NaN
# 22       0.0      NaN      NaN
# 23       0.0      NaN      NaN
# 24       0.0      NaN      NaN
# 25       0.0      NaN      NaN
# 26       0.0      NaN      NaN
# 27       0.0      NaN      NaN
# 28       0.0      NaN      NaN
# 29       0.0      NaN      NaN
# ...      ...      ...      ...
# 8730     0.0      NaN      NaN
# 8731     NaN      NaN      NaN
# 8732     NaN      NaN      NaN
# 8733     NaN      NaN      NaN
# 8734     NaN      NaN      NaN
# 8735     NaN      NaN      NaN
# 8736     NaN      NaN      NaN
# 8737     NaN      NaN      NaN
# 8738     NaN      NaN      NaN
# 8739     NaN      NaN      NaN
# 8740     NaN      NaN      NaN
# 8741     NaN      NaN      NaN
# 8742     NaN      NaN      NaN
# 8743     NaN      NaN      NaN
# 8744     0.0      NaN      NaN
# 8745     0.1      NaN      NaN
# 8746     0.0      NaN      NaN
# 8747     0.1      NaN      NaN
# 8748     0.2      NaN      NaN
# 8749     0.4      NaN      NaN
# 8750     0.3      NaN      NaN
# 8751     0.2      NaN      NaN
# 8752     0.6      NaN      NaN
# 8753     0.4      NaN      NaN
# 8754     0.0      NaN      NaN
# 8755     NaN      NaN      NaN
# 8756     NaN      NaN      NaN
# 8757     NaN      NaN      NaN
# 8758     NaN      NaN      NaN
# 8759     NaN      NaN      NaN
#
# [8760 rows x 9 columns]

# %% [markdown]
# ↑降水量の列はObject型となっているが、これは基本的に文字列型か、複数の型が混じってることを示している。

# %%
# 型の変換の確認
import numpy as np

df2 = df.copy()                                           #  dfに影響を及ぼさないように、コピーを作る
rains = np.array(df2["降水量(mm)"])      # 降水量を取り出して、1次元のndarray型に変更

for i in range(len(rains)):
    val = rains[i]
    if isinstance(val, str) and " )" in val:    # valが文字列か確認して、更に" )"が入っているかチェック
        val = val.replace(" )", "")
        print("要素{0}番目の値は{1}で、' )'を含んでいます。".format(i, val))
    if isinstance(val, str) and " ]" in val:
        val = val.replace(" ]", "")
        print("要素{0}番目の値は{1}で、' ]'を含んでいます。".format(i, val))
    rains[i] = val

df2["降水量(mm)"] = rains
df2["降水量(mm)"] = df2["降水量(mm)"].astype("float")    # 型の変換
print(df2.dtypes)      # 型の変換効果の確認
df2
# Out:
# 要素838番目の値は0.0で、' )'を含んでいます。
# 要素1506番目の値は0.0で、' )'を含んでいます。
# 要素1673番目の値は0.0で、' )'を含んでいます。
# 要素6692番目の値は0.0で、' )'を含んでいます。
# 要素8059番目の値は0.0で、' )'を含んでいます。
# 要素8363番目の値は0.0で、' )'を含んでいます。
# 要素8369番目の値は0.0で、' )'を含んでいます。
# 日時               object
# 時                 int64
# 降水量(mm)         float64
# 気温(度)           float64
# 風速・風向(m/s)風速     object
# 風速・風向(m/s)風向     object
# 日照時間(h)          object
# 雪(cm)降雪         float64
# 雪(cm)積雪         float64
# dtype: object
#                        日時   時  降水量(mm)  気温(度) 風速・風向(m/s)風速 風速・風向(m/s)風向  \
# 0     2009-01-01 00:00:00  24      0.0    4.1            3          北北西
# 1     2009-01-01 01:00:00   1      0.0    4.4            4          北北西
# 2     2009-01-01 02:00:00   2      0.0    4.9            7          西北西
# 3     2009-01-01 03:00:00   3      0.0    4.3            4           北西
# 4     2009-01-01 04:00:00   4      0.0    3.4            2          北北西
# 5     2009-01-01 05:00:00   5      0.0    3.7            4           北西
# 6     2009-01-01 06:00:00   6      0.0    2.8            3            北
# 7     2009-01-01 07:00:00   7      0.0    2.9            3            北
# 8     2009-01-01 08:00:00   8      0.0    3.1            2          北北西
# 9     2009-01-01 09:00:00   9      0.0    4.2            4          北北東
# 10    2009-01-01 10:00:00  10      0.0    2.5            5          北北西
# 11    2009-01-01 11:00:00  11      0.0    4.0            5          北北西
# 12    2009-01-01 12:00:00  12      0.0    4.8            4          北北西
# 13    2009-01-01 13:00:00  13      0.0    5.3            4           北西
# 14    2009-01-01 14:00:00  14      0.0    4.1            6          北北西
# 15    2009-01-01 15:00:00  15      0.0    4.1            6          北北西
# 16    2009-01-01 16:00:00  16      0.0    3.8            6          北北西
# 17    2009-01-01 17:00:00  17      0.0    3.2            4           北西
# 18    2009-01-01 18:00:00  18      0.0    2.2            3           北西
# 19    2009-01-01 19:00:00  19      0.0    2.3            3          北北西
# 20    2009-01-01 20:00:00  20      0.0    1.6            1            西
# 21    2009-01-01 21:00:00  21      0.0    2.7            2           南西
# 22    2009-01-01 22:00:00  22      0.0    2.7            1            西
# 23    2009-01-01 23:00:00  23      0.0    2.5            2            西
# 24    2009-01-02 00:00:00  24      0.0    2.8            2          西北西
# 25    2009-01-02 01:00:00   1      0.0    2.3            2          北北西
# 26    2009-01-02 02:00:00   2      0.0    2.4            2          北北西
# 27    2009-01-02 03:00:00   3      0.0    2.3            2          北北西
# 28    2009-01-02 04:00:00   4      0.0    0.6            1           北西
# 29    2009-01-02 05:00:00   5      0.0   -0.1            1          北北東
# ...                   ...  ..      ...    ...          ...          ...
# 8730  2009-12-30 18:00:00  18      0.0    8.3          2.0          西北西
# 8731  2009-12-30 19:00:00  19      0.0    7.9          2.5          西北西
# 8732  2009-12-30 20:00:00  20      0.0    7.6          2.8           南西
# 8733  2009-12-30 21:00:00  21      0.0    7.2          4.4          北北西
# 8734  2009-12-30 22:00:00  22      0.0    6.5          4.1          西北西
# 8735  2009-12-30 23:00:00  23      0.0    6.0          3.9           北西
# 8736  2009-12-31 00:00:00  24      0.0    5.8          5.0           北西
# 8737  2009-12-31 01:00:00   1      0.0    5.4          4.5          西北西
# 8738  2009-12-31 02:00:00   2      0.0    5.1          3.5           北西
# 8739  2009-12-31 03:00:00   3      0.0    4.3          3.5          北北西
# 8740  2009-12-31 04:00:00   4      0.0    3.4          4.2          北北西
# 8741  2009-12-31 05:00:00   5      0.0    3.0          5.4          北北西
# 8742  2009-12-31 06:00:00   6      0.0    2.4          5.4          北北西
# 8743  2009-12-31 07:00:00   7      0.0    2.4          7.3           北西
# 8744  2009-12-31 08:00:00   8      0.0    2.7          4.9            北
# 8745  2009-12-31 09:00:00   9      0.0    2.7          3.9          北北西
# 8746  2009-12-31 10:00:00  10      0.0    3.0          4.2          北北西
# 8747  2009-12-31 11:00:00  11      0.0    3.3          5.0          北北西
# 8748  2009-12-31 12:00:00  12      0.0    4.1          5.6           北西
# 8749  2009-12-31 13:00:00  13      0.0    4.6          4.5           北西
# 8750  2009-12-31 14:00:00  14      0.0    3.4          5.0          北北西
# 8751  2009-12-31 15:00:00  15      0.0    3.7          4.7           北西
# 8752  2009-12-31 16:00:00  16      0.0    3.4          5.3          西北西
# 8753  2009-12-31 17:00:00  17      0.0    2.8          2.7            北
# 8754  2009-12-31 18:00:00  18      0.0    2.2          2.7          北北東
# 8755  2009-12-31 19:00:00  19      0.0    2.1          2.6            北
# 8756  2009-12-31 20:00:00  20      0.0    1.4          0.6            北
# 8757  2009-12-31 21:00:00  21      0.0    1.8          3.0           北西
# 8758  2009-12-31 22:00:00  22      0.0    1.8          4.2           北西
# 8759  2009-12-31 23:00:00  23      0.0    1.5          3.1          北北西
#
#      日照時間(h)  雪(cm)降雪  雪(cm)積雪
# 0        0.0      NaN      NaN
# 1        0.0      NaN      NaN
# 2        0.0      NaN      NaN
# 3        0.0      NaN      NaN
# 4        0.0      NaN      NaN
# 5        0.0      NaN      NaN
# 6        0.0      NaN      NaN
# 7        0.0      NaN      NaN
# 8        0.1      NaN      NaN
# 9        0.5      NaN      NaN
# 10       0.7      NaN      NaN
# 11       0.1      NaN      NaN
# 12       0.3      NaN      NaN
# 13       0.2      NaN      NaN
# 14       0.3      NaN      NaN
# 15       0.3      NaN      NaN
# 16       0.0      NaN      NaN
# 17       0.0      NaN      NaN
# 18       0.0      NaN      NaN
# 19       0.0      NaN      NaN
# 20       0.0      NaN      NaN
# 21       0.0      NaN      NaN
# 22       0.0      NaN      NaN
# 23       0.0      NaN      NaN
# 24       0.0      NaN      NaN
# 25       0.0      NaN      NaN
# 26       0.0      NaN      NaN
# 27       0.0      NaN      NaN
# 28       0.0      NaN      NaN
# 29       0.0      NaN      NaN
# ...      ...      ...      ...
# 8730     0.0      NaN      NaN
# 8731     NaN      NaN      NaN
# 8732     NaN      NaN      NaN
# 8733     NaN      NaN      NaN
# 8734     NaN      NaN      NaN
# 8735     NaN      NaN      NaN
# 8736     NaN      NaN      NaN
# 8737     NaN      NaN      NaN
# 8738     NaN      NaN      NaN
# 8739     NaN      NaN      NaN
# 8740     NaN      NaN      NaN
# 8741     NaN      NaN      NaN
# 8742     NaN      NaN      NaN
# 8743     NaN      NaN      NaN
# 8744     0.0      NaN      NaN
# 8745     0.1      NaN      NaN
# 8746     0.0      NaN      NaN
# 8747     0.1      NaN      NaN
# 8748     0.2      NaN      NaN
# 8749     0.4      NaN      NaN
# 8750     0.3      NaN      NaN
# 8751     0.2      NaN      NaN
# 8752     0.6      NaN      NaN
# 8753     0.4      NaN      NaN
# 8754     0.0      NaN      NaN
# 8755     NaN      NaN      NaN
# 8756     NaN      NaN      NaN
# 8757     NaN      NaN      NaN
# 8758     NaN      NaN      NaN
# 8759     NaN      NaN      NaN
#
# [8760 rows x 9 columns]

# %% [markdown]
# ↑"降水量(mm)         float64"とあるので、降水量の列を文字列型からfloat型（数値型）に変換できた事がわかる。

# %%
#解答例

def str2float(df, coloum_name):
    """ 引数で指定された列の変数型を文字列からfloat型に変換したDataFrameを返す
    """
    df2 = df.copy()                                           #  dfに影響を及ぼさないように、コピーを作る
    rains = np.array(df2[coloum_name])      # coloum_name列を取り出して、1次元のndarray型に変更

    for i in range(len(rains)):
        val = rains[i]
        if isinstance(val, str) and " )" in val:    # valが文字列か確認して、更に" )"が入っているかチェック
            val = val.replace(" )", "")
            #print("要素{0}番目の値は{1}で、' )'を含んでいます。".format(i, val))    # 確認後にコメントアウト
        if isinstance(val, str) and " ]" in val:
            val = val.replace(" ]", "")
            #print("要素{0}番目の値は{1}で、' ]'を含んでいます。".format(i, val))
        rains[i] = val

    df2[coloum_name] = rains
    df2[coloum_name] = df2[coloum_name].astype("float")    # 型の変換
    
    return df2


def test(df):
    # 降水量の項目を数値化する
    df = str2float(df, "降水量(mm)")
    
    # 雨量が10 mmを超える時間のみ抽出して、その件数をカウント
    df_rain10 = df[df["降水量(mm)"] >= 10]
    y = len(df_rain10)
    
    return y


def main():
    # データの読み込み
    amedas_df = pd.read_csv("https://raw.githubusercontent.com/KatsuhiroMorishita/numeric_calculation_with_python/master/Pandas/amedas_0962_mini.csv", na_values=["×", "--", "///"])    # 可能な限り、欠損値はNaNに置換する
    
    # データの処理と表示
    print(test(amedas_df))

if __name__ == "__main__":
    main()
# Out:
# 42

# %% [markdown]
# ↑42が雨量が10 [mm/h]を超えた時間数である。
