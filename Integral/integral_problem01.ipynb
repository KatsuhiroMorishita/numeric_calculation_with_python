# %% [markdown]
# # 出題内容
# 以下の式において、−10≤𝑥≤10の範囲で積分せよ。
#
# ![数式](integral_p01_1.JPG)

# %%
# (1)の解答例
import numpy as np
import matplotlib.pyplot as plt

# jupyter notebookでノート内にグラフを描画させる特殊命令
# %matplotlib inline

def func(x):
    """ 式(1)の計算結果を返す
    """
    return (3.9**x) * (np.sin(x)**3)

def integral(f, x1, x2, dx): # 定積分（汎用）
    """ x1からx2までの定積分を返す
    f: 積分したい関数
    dx: xの微小変化量
    """
    x = np.arange(x1, x2, dx)
    ds = (f(x + dx) + f(x)) / 2.0 * dx # 台形積分するつもりで、その微小面積dsを求める
    s = np.sum(ds) # 面積
    return s


def main():  
    x1, x2, dx = -10, 10, 0.01 # 積分範囲と、微小量
    print("積分値は、", integral(func, x1, x2, dx))
    
    # グラフ作成
    x = np.arange(x1, x2, dx)
    y = func(x)
    plt.plot(x, y)
    plt.grid()
    plt.show()

        
if __name__ == "__main__":
    main()
# Out:
# 積分値は、 55008.86517484001

# %%
# (2)の解答例
import numpy as np
import matplotlib.pyplot as plt

# jupyter notebookでノート内にグラフを描画させる特殊命令
# %matplotlib inline

a, b, c = 5, -6, -20 # 係数はテキトーに決めた

def func(x):
    """ 式(2)の計算結果を返す
    """
    return a * x**2 + b * x - c  # 関数内に宣言されていない変数はその外のものが使われる

def integral(f, x1, x2, dx): # 定積分（汎用）
    """ x1からx2までの定積分を返す
    f: 積分したい関数
    dx: xの微小変化量
    """
    x = np.arange(x1, x2, dx)
    ds = (f(x + dx) + f(x)) / 2.0 * dx # 台形積分するつもりで、その微小面積dsを求める
    s = np.sum(ds) # 面積
    return s


def main():  
    x1, x2, dx = -10, 10, 0.01 # 積分範囲と、微小量
    print("積分値は、", integral(func, x1, x2, dx))
    
    # グラフ作成
    x = np.arange(x1, x2, dx)
    y = func(x)
    plt.plot(x, y)
    plt.grid()
    plt.show()

        
if __name__ == "__main__":
    main()
# Out:
# 積分値は、 3733.334999999884
